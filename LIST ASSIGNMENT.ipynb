# %%
#3
List1 = ["Mike", "Emma", "", "Kelly", "Brad"]
List1 = list(filter(None, List1))
print(List1)
# Out:
# ['Mike', 'Emma', 'Kelly', 'Brad']

# %%
#4
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
#5
list1 = [5, 10, 15, 20, 25, 50, 20]
index=list1.index(20)
list1[index]=200
print(list1)
# Out:
# [5, 10, 15, 200, 25, 50, 20]

# %%
#6
numbers=[25,15,2,7,9,4,2]
largest=max(numbers)
smallest=min(numbers)
range=largest-smallest
print(range)
# Out:
# 23

# %%
#8
number=[10,20,30,40,50]
new_element=int(input("Enter the new element: "))
index=int(input("Enter the index: "))
number.insert(index,new_element)
print(number)
# Out:
# Enter the new element: 60
# Enter the index: 6
# [10, 20, 30, 40, 50, 60]

# %%
#1
numbers=[1,2,3,4,5,7,8]
total=sum(numbers)
print(total)
# Out:
# 30

# %%
#2
letter=['a','b','c','d','e']
reversed_letter=letter[::-1]
print(reversed_letter)
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
#7
import random
random_number=[random.randint(1,10) for _ in range(20)]
print(random_number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-e9be6357f807> in <cell line: 3>()
#       1 #7
#       2 import random
# ----> 3 random_number=[random.randint(1,10) for _ in range(20)]
#       4 print(random_number)
#       5
#
# TypeError: 'int' object is not callable
